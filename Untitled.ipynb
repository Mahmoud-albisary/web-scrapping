# %%
import requests
from bs4 import BeautifulSoup
import pandas

r = requests.get("https://www.century21.com/real-estate/rock-spring-ga/LCGAROCKSPRING/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content

content = BeautifulSoup(c, "html.parser")
all = content.find_all("div", {"class":"property-card-primary-info"})
a = []
for items in all:
    d = {}
    x = items.find("div", {"class":"property-beds"})
    d["price"] = items.find("a", {"class":"listing-price"}).text.replace("\n","").replace(" ", "")
    d["city"] = items.find("div", {"class":"property-city"}).text.replace("\n","").replace(" ","")
    d["address"] = items.find("div", {"class":"property-address"}).text.replace("\n","").replace(" ", "")
    if x != None:
        for items in x.text:
            try :
                int(items)
                d["beds"] = items
            except:
                pass
    else:
        d["beds"] = None
    print(" ")
    a.append(d)
df = pandas.DataFrame(a)
df.to_csv("finals.xlsx")
print(df)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          price                city                        address  beds
# 0     $449,900  RockSpringsGA30739             1093BicentennialTr     5
# 1     $188,900   RockSpringGA30739                   177CattailDr     3
# 2     $259,900   RockSpringGA30739             115GingerLakeDrive     4
# 3     $241,900   RockSpringGA30739                754GingerLakeDr     3
# 4     $340,000   RockSpringGA30739              512WindingRidgeRd     4
# 5     $340,000   RockSpringGA30739                512WindingRidge     4
# 6      $52,000   RockSpringGA30739                  000McintireRd  None
# 7       $9,000   RockSpringGA30739                       OldHwy27  None
# 8     $164,900   RockSpringGA30739                FieldstoneDrive  None
# 9      $15,995   RockSpringGA30739                   PeavineWay23  None
# 10  $1,700,000   RockSpringGA30739                    -NHighway27  None
# 11    $550,000   RockSpringGA30739                    10161NHwy27  None
# 12    $500,000   RockSpringGA30739  00Phase2GingerLakeEstatesDr58  None
# 13    $425,000   RockSpringGA30739                15590AlabamaHwy     3
# 14    $350,000   RockSpringGA30739                    67TrinityLn     3
# 15    $339,000   RockSpringGA30739                 197FarmViewCir     4
# 16    $283,500   RockSpringGA30739               376GuyWilliamsRd  None
# 17    $275,000   RockSpringGA30739                 50TwelveOaksDr     4
# 18    $274,900   RockSpringGA30739                 31GingerLakeDr     3
# 19    $269,000   RockSpringGA30739                    189ArnoldRd     3

# %%
import requests
from bs4 import BeautifulSoup
import pandas

r = requests.get("https://www.century21.com/real-estate/rock-spring-ga/LCGAROCKSPRING/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content
content = BeautifulSoup(c, "html.parser")
all = content.find_all("div", {"class":"property-card-primary-info"})
a = []
for items in all:
    d = {}
    x = items.find("div", {"class":"property-beds"})
    d["price"] = items.find("a", {"class":"listing-price"}).text.replace("\n","").replace(" ", "")
    d["city"] = items.find("div", {"class":"property-city"}).text.replace("\n","").replace(" ","")
    d["address"] = items.find("div", {"class":"property-address"}).text.replace("\n","").replace(" ", "")
    if x != None:
        for items in x.text:
            try :
                int(items)
                d["beds"] = str(items)
            except:
                pass
    else:
        d["beds"] = None
    print(" ")
    a.append(d)
df = pandas.DataFrame(a)
df.to_csv("final.csv")
print(df)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          price                city                        address  beds
# 0     $449,900  RockSpringsGA30739             1093BicentennialTr     5
# 1     $188,900   RockSpringGA30739                   177CattailDr     3
# 2     $259,900   RockSpringGA30739             115GingerLakeDrive     4
# 3     $241,900   RockSpringGA30739                754GingerLakeDr     3
# 4     $340,000   RockSpringGA30739              512WindingRidgeRd     4
# 5     $340,000   RockSpringGA30739                512WindingRidge     4
# 6      $52,000   RockSpringGA30739                  000McintireRd  None
# 7       $9,000   RockSpringGA30739                       OldHwy27  None
# 8     $164,900   RockSpringGA30739                FieldstoneDrive  None
# 9      $15,995   RockSpringGA30739                   PeavineWay23  None
# 10  $1,700,000   RockSpringGA30739                    -NHighway27  None
# 11    $550,000   RockSpringGA30739                    10161NHwy27  None
# 12    $500,000   RockSpringGA30739  00Phase2GingerLakeEstatesDr58  None
# 13    $425,000   RockSpringGA30739                15590AlabamaHwy     3
# 14    $350,000   RockSpringGA30739                    67TrinityLn     3
# 15    $339,000   RockSpringGA30739                 197FarmViewCir     4
# 16    $283,500   RockSpringGA30739               376GuyWilliamsRd  None
# 17    $275,000   RockSpringGA30739                 50TwelveOaksDr     4
# 18    $274,900   RockSpringGA30739                 31GingerLakeDr     3
# 19    $269,000   RockSpringGA30739                    189ArnoldRd     3

# %%
import requests
from bs4 import BeautifulSoup
import pandas

r = requests.get("https://www.century21.com/real-estate/rock-spring-ga/LCGAROCKSPRING/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content
content = BeautifulSoup(c, "html.parser")
all = content.find_all("div", {"class":"property-card-primary-info"})
a = []
for items in all:
    d = {}
    x = items.find("div", {"class":"property-beds"})
    d["price"] = items.find("a", {"class":"listing-price"}).text.replace("\n","").replace(" ", "")
    d["city"] = items.find("div", {"class":"property-city"}).text.replace("\n","").replace(" ","")
    d["address"] = items.find("div", {"class":"property-address"}).text.replace("\n","").replace(" ", "")
    if x != None:
        for items in x.text:
            try :
                int(items)
                d["beds"] = str(items)
            except:
                pass
    else:
        d["beds"] = None
    print(" ")
    a.append(d)
df = pandas.DataFrame(a)
df.to_csv("final.csv")
print(df)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          price                city                        address  beds
# 0     $449,900  RockSpringsGA30739             1093BicentennialTr     5
# 1     $188,900   RockSpringGA30739                   177CattailDr     3
# 2     $259,900   RockSpringGA30739             115GingerLakeDrive     4
# 3     $241,900   RockSpringGA30739                754GingerLakeDr     3
# 4     $340,000   RockSpringGA30739              512WindingRidgeRd     4
# 5     $340,000   RockSpringGA30739                512WindingRidge     4
# 6      $52,000   RockSpringGA30739                  000McintireRd  None
# 7       $9,000   RockSpringGA30739                       OldHwy27  None
# 8     $164,900   RockSpringGA30739                FieldstoneDrive  None
# 9      $15,995   RockSpringGA30739                   PeavineWay23  None
# 10  $1,700,000   RockSpringGA30739                    -NHighway27  None
# 11    $550,000   RockSpringGA30739                    10161NHwy27  None
# 12    $500,000   RockSpringGA30739  00Phase2GingerLakeEstatesDr58  None
# 13    $425,000   RockSpringGA30739                15590AlabamaHwy     3
# 14    $350,000   RockSpringGA30739                    67TrinityLn     3
# 15    $339,000   RockSpringGA30739                 197FarmViewCir     4
# 16    $283,500   RockSpringGA30739               376GuyWilliamsRd  None
# 17    $275,000   RockSpringGA30739                 50TwelveOaksDr     4
# 18    $274,900   RockSpringGA30739                 31GingerLakeDr     3
# 19    $269,000   RockSpringGA30739                    189ArnoldRd     3

# %%
import requests
from bs4 import BeautifulSoup
import pandas

r = requests.get("https://www.century21.com/real-estate/rock-spring-ga/LCGAROCKSPRING/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content
content = BeautifulSoup(c, "html.parser")
all = content.find_all("div", {"class":"property-card-primary-info"})
a = []
for items in all:
    d = {}
    x = items.find("div", {"class":"property-beds"})
    d["price"] = items.find("a", {"class":"listing-price"}).text.replace("\n","").replace(" ", "")
    d["city"] = items.find("div", {"class":"property-city"}).text.replace("\n","").replace(" ","")
    d["address"] = items.find("div", {"class":"property-address"}).text.replace("\n","").replace(" ", "")
    if x != None:
        d["beds"] = x.text
    else:
        d["beds"] = "None"
    print(" ")
    a.append(d)
df = pandas.DataFrame(a)
df.to_csv("final.csv")
print(df)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          price                city                        address  \
# 0     $449,900  RockSpringsGA30739             1093BicentennialTr
# 1     $188,900   RockSpringGA30739                   177CattailDr
# 2     $259,900   RockSpringGA30739             115GingerLakeDrive
# 3     $241,900   RockSpringGA30739                754GingerLakeDr
# 4     $340,000   RockSpringGA30739              512WindingRidgeRd
# 5     $340,000   RockSpringGA30739                512WindingRidge
# 6      $52,000   RockSpringGA30739                  000McintireRd
# 7       $9,000   RockSpringGA30739                       OldHwy27
# 8     $164,900   RockSpringGA30739                FieldstoneDrive
# 9      $15,995   RockSpringGA30739                   PeavineWay23
# 10  $1,700,000   RockSpringGA30739                    -NHighway27
# 11    $550,000   RockSpringGA30739                    10161NHwy27
# 12    $500,000   RockSpringGA30739  00Phase2GingerLakeEstatesDr58
# 13    $425,000   RockSpringGA30739                15590AlabamaHwy
# 14    $350,000   RockSpringGA30739                    67TrinityLn
# 15    $339,000   RockSpringGA30739                 197FarmViewCir
# 16    $283,500   RockSpringGA30739               376GuyWilliamsRd
# 17    $275,000   RockSpringGA30739                 50TwelveOaksDr
# 18    $274,900   RockSpringGA30739                 31GingerLakeDr
# 19    $269,000   RockSpringGA30739                    189ArnoldRd
#
#                    beds
# 0   \n5 beds\n
# 1   \n3 beds\n
# 2   \n4 beds\n
# 3   \n3 beds\n
# 4   \n4 beds\n
# 5   \n4 beds\n
# 6                  None
# 7                  None
# 8                  None
# 9                  None
# 10                 None
# 11                 None
# 12                 None
# 13  \n3 beds\n
# 14  \n3 beds\n
# 15  \n4 beds\n
# 16                 None
# 17  \n4 beds\n
# 18  \n3 beds\n
# 19  \n3 beds\n

# %%
import requests
from bs4 import BeautifulSoup
import pandas

r = requests.get("https://www.century21.com/real-estate/rock-spring-ga/LCGAROCKSPRING/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content
content = BeautifulSoup(c, "html.parser")
all = content.find_all("div", {"class":"property-card-primary-info"})
a = []
for items in all:
    d = {}
    x = items.find("div", {"class":"property-beds"})
    d["price"] = items.find("a", {"class":"listing-price"}).text.replace("\n","").replace(" ", "")
    d["city"] = items.find("div", {"class":"property-city"}).text.replace("\n","").replace(" ","")
    d["address"] = items.find("div", {"class":"property-address"}).text.replace("\n","").replace(" ", "")
    if x != None:
        d["beds"] = x.text.replace("\n","").replace(" ", "")
    else:
        d["beds"] = "None"
    print(" ")
    a.append(d)
df = pandas.DataFrame(a)
df.to_csv("final.csv")
print(df)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          price                city                        address   beds
# 0     $449,900  RockSpringsGA30739             1093BicentennialTr  5beds
# 1     $188,900   RockSpringGA30739                   177CattailDr  3beds
# 2     $259,900   RockSpringGA30739             115GingerLakeDrive  4beds
# 3     $241,900   RockSpringGA30739                754GingerLakeDr  3beds
# 4     $340,000   RockSpringGA30739              512WindingRidgeRd  4beds
# 5     $340,000   RockSpringGA30739                512WindingRidge  4beds
# 6      $52,000   RockSpringGA30739                  000McintireRd   None
# 7       $9,000   RockSpringGA30739                       OldHwy27   None
# 8     $164,900   RockSpringGA30739                FieldstoneDrive   None
# 9      $15,995   RockSpringGA30739                   PeavineWay23   None
# 10  $1,700,000   RockSpringGA30739                    -NHighway27   None
# 11    $550,000   RockSpringGA30739                    10161NHwy27   None
# 12    $500,000   RockSpringGA30739  00Phase2GingerLakeEstatesDr58   None
# 13    $425,000   RockSpringGA30739                15590AlabamaHwy  3beds
# 14    $350,000   RockSpringGA30739                    67TrinityLn  3beds
# 15    $339,000   RockSpringGA30739                 197FarmViewCir  4beds
# 16    $283,500   RockSpringGA30739               376GuyWilliamsRd   None
# 17    $275,000   RockSpringGA30739                 50TwelveOaksDr  4beds
# 18    $274,900   RockSpringGA30739                 31GingerLakeDr  3beds
# 19    $269,000   RockSpringGA30739                    189ArnoldRd  3beds

# %%
import requests
from bs4 import BeautifulSoup
import pandas

r = requests.get("https://www.century21.com/real-estate/rock-spring-ga/LCGAROCKSPRING/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content
content = BeautifulSoup(c, "html.parser")
all = content.find_all("div", {"class":"property-card-primary-info"})
a = []
for items in all:
    d = {}
    x = items.find("div", {"class":"property-beds"})
    d["price"] = items.find("a", {"class":"listing-price"}).text.replace("\n","").replace(" ", "")
    d["city"] = items.find("div", {"class":"property-city"}).text.replace("\n","").replace(" ","")
    d["address"] = items.find("div", {"class":"property-address"}).text.replace("\n","").replace(" ", "")
    if x != None:
        d["beds"] = x.text.replace("\n","").replace(" ", "")
    else:
        d["beds"] = "Unknown"
    print(" ")
    a.append(d)
df = pandas.DataFrame(a)
df.to_csv("final.csv")
print(df)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          price                city                        address     beds
# 0     $449,900  RockSpringsGA30739             1093BicentennialTr    5beds
# 1     $188,900   RockSpringGA30739                   177CattailDr    3beds
# 2     $259,900   RockSpringGA30739             115GingerLakeDrive    4beds
# 3     $241,900   RockSpringGA30739                754GingerLakeDr    3beds
# 4     $340,000   RockSpringGA30739              512WindingRidgeRd    4beds
# 5     $340,000   RockSpringGA30739                512WindingRidge    4beds
# 6      $52,000   RockSpringGA30739                  000McintireRd  Unknown
# 7       $9,000   RockSpringGA30739                       OldHwy27  Unknown
# 8     $164,900   RockSpringGA30739                FieldstoneDrive  Unknown
# 9      $15,995   RockSpringGA30739                   PeavineWay23  Unknown
# 10  $1,700,000   RockSpringGA30739                    -NHighway27  Unknown
# 11    $550,000   RockSpringGA30739                    10161NHwy27  Unknown
# 12    $500,000   RockSpringGA30739  00Phase2GingerLakeEstatesDr58  Unknown
# 13    $425,000   RockSpringGA30739                15590AlabamaHwy    3beds
# 14    $350,000   RockSpringGA30739                    67TrinityLn    3beds
# 15    $339,000   RockSpringGA30739                 197FarmViewCir    4beds
# 16    $283,500   RockSpringGA30739               376GuyWilliamsRd  Unknown
# 17    $275,000   RockSpringGA30739                 50TwelveOaksDr    4beds
# 18    $274,900   RockSpringGA30739                 31GingerLakeDr    3beds
# 19    $269,000   RockSpringGA30739                    189ArnoldRd    3beds

# %%
import requests
from bs4 import BeautifulSoup
import pandas

r = requests.get("https://www.century21.com/real-estate/rock-spring-ga/LCGAROCKSPRING/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content
content = BeautifulSoup(c, "html.parser")
all = content.find_all("div", {"class":"property-card-primary-info"})
a = []
for items in all:
    d = {}
    x = items.find("div", {"class":"property-beds"})
    d["price"] = items.find("a", {"class":"listing-price"}).text.replace("\n","").replace(" ", "")
    d["city"] = items.find("div", {"class":"property-city"}).text.replace("\n","").replace(" ","")
    d["address"] = items.find("div", {"class":"property-address"}).text.replace("\n","").replace(" ", "")
    if x != None:
        d["beds"] = x.text.replace("\n","").replace(" ", "")
    else:
        d["beds"] = "Unknown"
    print(" ")
    a.append(d)
df = pandas.DataFrame(a)
df.to_csv("final.csv")
print(df)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          price                city                        address     beds
# 0     $449,900  RockSpringsGA30739             1093BicentennialTr    5beds
# 1     $188,900   RockSpringGA30739                   177CattailDr    3beds
# 2     $259,900   RockSpringGA30739             115GingerLakeDrive    4beds
# 3     $241,900   RockSpringGA30739                754GingerLakeDr    3beds
# 4     $340,000   RockSpringGA30739              512WindingRidgeRd    4beds
# 5     $340,000   RockSpringGA30739                512WindingRidge    4beds
# 6      $52,000   RockSpringGA30739                  000McintireRd  Unknown
# 7       $9,000   RockSpringGA30739                       OldHwy27  Unknown
# 8     $164,900   RockSpringGA30739                FieldstoneDrive  Unknown
# 9      $15,995   RockSpringGA30739                   PeavineWay23  Unknown
# 10  $1,700,000   RockSpringGA30739                    -NHighway27  Unknown
# 11    $550,000   RockSpringGA30739                    10161NHwy27  Unknown
# 12    $500,000   RockSpringGA30739  00Phase2GingerLakeEstatesDr58  Unknown
# 13    $425,000   RockSpringGA30739                15590AlabamaHwy    3beds
# 14    $350,000   RockSpringGA30739                    67TrinityLn    3beds
# 15    $339,000   RockSpringGA30739                 197FarmViewCir    4beds
# 16    $283,500   RockSpringGA30739               376GuyWilliamsRd  Unknown
# 17    $275,000   RockSpringGA30739                 50TwelveOaksDr    4beds
# 18    $274,900   RockSpringGA30739                 31GingerLakeDr    3beds
# 19    $269,000   RockSpringGA30739                    189ArnoldRd    3beds

# %%
import requests
from bs4 import BeautifulSoup
import pandas

r = requests.get("https://www.century21.com/real-estate/rock-spring-ga/LCGAROCKSPRING/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content
content = BeautifulSoup(c, "html.parser")
all = content.find_all("div", {"class":"property-card-primary-info"})
a = []
for items in all:
    d = {}
    x = items.find("div", {"class":"property-beds"})
    d["price"] = items.find("a", {"class":"listing-price"}).text.replace("\n","").replace(" ", "")
    d["city"] = items.find("div", {"class":"property-city"}).text.replace("\n","").replace(" ","")
    d["address"] = items.find("div", {"class":"property-address"}).text.replace("\n","").replace(" ", "")
    if x != None:
        for items in x.text.replace("\n","").replace(" ", ""):
            d["beds"] = items

    else:
        d["beds"] = "Unknown"
    print(" ")
    a.append(d)
df = pandas.DataFrame(a)
df.to_csv("final.csv")
print(df)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          price                city                        address     beds
# 0     $449,900  RockSpringsGA30739             1093BicentennialTr        s
# 1     $188,900   RockSpringGA30739                   177CattailDr        s
# 2     $259,900   RockSpringGA30739             115GingerLakeDrive        s
# 3     $241,900   RockSpringGA30739                754GingerLakeDr        s
# 4     $340,000   RockSpringGA30739              512WindingRidgeRd        s
# 5     $340,000   RockSpringGA30739                512WindingRidge        s
# 6      $52,000   RockSpringGA30739                  000McintireRd  Unknown
# 7       $9,000   RockSpringGA30739                       OldHwy27  Unknown
# 8     $164,900   RockSpringGA30739                FieldstoneDrive  Unknown
# 9      $15,995   RockSpringGA30739                   PeavineWay23  Unknown
# 10  $1,700,000   RockSpringGA30739                    -NHighway27  Unknown
# 11    $550,000   RockSpringGA30739                    10161NHwy27  Unknown
# 12    $500,000   RockSpringGA30739  00Phase2GingerLakeEstatesDr58  Unknown
# 13    $425,000   RockSpringGA30739                15590AlabamaHwy        s
# 14    $350,000   RockSpringGA30739                    67TrinityLn        s
# 15    $339,000   RockSpringGA30739                 197FarmViewCir        s
# 16    $283,500   RockSpringGA30739               376GuyWilliamsRd  Unknown
# 17    $275,000   RockSpringGA30739                 50TwelveOaksDr        s
# 18    $274,900   RockSpringGA30739                 31GingerLakeDr        s
# 19    $269,000   RockSpringGA30739                    189ArnoldRd        s

# %%
import requests
from bs4 import BeautifulSoup
import pandas

r = requests.get("https://www.century21.com/real-estate/rock-spring-ga/LCGAROCKSPRING/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content
content = BeautifulSoup(c, "html.parser")
all = content.find_all("div", {"class":"property-card-primary-info"})
a = []
for items in all:
    d = {}
    x = items.find("div", {"class":"property-beds"})
    d["price"] = items.find("a", {"class":"listing-price"}).text.replace("\n","").replace(" ", "")
    d["city"] = items.find("div", {"class":"property-city"}).text.replace("\n","").replace(" ","")
    d["address"] = items.find("div", {"class":"property-address"}).text.replace("\n","").replace(" ", "")
    if x != None:
        for items in x.text.replace("\n","").replace(" ", ""):
            try int(items):
                d["beds"] = items
            except:
                pass
    else:
        d["beds"] = "Unknown"
    print(" ")
    a.append(d)
df = pandas.DataFrame(a)
df.to_csv("final.csv")
print(df)
# Out:
#   File "<ipython-input-17-21992037204f>", line 18
#     try int(items):
#           ^
# SyntaxError: invalid syntax
